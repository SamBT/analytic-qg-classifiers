# %%
from master import *

# %%
fq = prefix+'H2qq-CF3.0CA3.0-sqg0100-esq0011/total.root'
X,Y = tools.pre_process(fq,f_gluon,nev_max=50000)
z = np.array([[p[0] for p in jet] for jet in X])
mults = [np.sum([1 if zi > 0 else 0 for zi in jet]) for jet in z]
optimal = an.nk(z,1) + an.nk(z,2)
# Out:
# Finished preprocessing at 12.246625661849976

# %%
pfn, pfn_roc, pfn_auc = tools.train_qg_pfn(X,Y,n_epoch=3,summary=False)
pfn_z, pfn_z_roc, pfn_z_auc = tools.train_qg_pfn_no_angular(X,Y,n_epoch=3,summary=False)
pfn_noz, pfn_noz_roc, pfn_noz_auc = tools.train_qg_pfn_only_angular(X,Y,n_epoch=3,summary=False)
efn, efn_roc, efn_auc = tools.train_qg_efn(X,Y,n_epoch=3,summary=False)
# Out:
# Model summary:
# Train on 70000 samples, validate on 15000 samples
# Epoch 1/3
# 70000/70000 [==============================] - 2s 34us/step - loss: 0.6947 - acc: 0.5617 - val_loss: 0.6711 - val_acc: 0.5903
# Epoch 2/3
# 70000/70000 [==============================] - 1s 16us/step - loss: 0.6748 - acc: 0.5864 - val_loss: 0.6694 - val_acc: 0.5923
# Epoch 3/3
# 70000/70000 [==============================] - 1s 15us/step - loss: 0.6685 - acc: 0.5973 - val_loss: 0.6640 - val_acc: 0.5992
# Finished training at 5.429815292358398
#
# PFN AUC: 0.6322798134374653
#
# Model summary:
# Train on 70000 samples, validate on 15000 samples
# Epoch 1/3
# 70000/70000 [==============================] - 2s 24us/step - loss: 0.7009 - acc: 0.5162 - val_loss: 0.6895 - val_acc: 0.5426
# Epoch 2/3
# 70000/70000 [==============================] - 1s 15us/step - loss: 0.6899 - acc: 0.5370 - val_loss: 0.6885 - val_acc: 0.5414
# Epoch 3/3
# 70000/70000 [==============================] - 1s 16us/step - loss: 0.6891 - acc: 0.5415 - val_loss: 0.6882 - val_acc: 0.5429
# Finished training at 4.752723455429077
#
# PFN AUC: 0.5740491626703647
# Model summary:
# Train on 70000 samples, validate on 15000 samples
# Epoch 1/3
# 70000/70000 [==============================] - 2s 26us/step - loss: 0.7011 - acc: 0.5598 - val_loss: 0.6726 - val_acc: 0.5883
# Epoch 2/3
# 70000/70000 [==============================] - 1s 16us/step - loss: 0.6732 - acc: 0.5888 - val_loss: 0.6670 - val_acc: 0.5990
# Epoch 3/3
# 70000/70000 [==============================] - 1s 16us/step - loss: 0.6702 - acc: 0.5918 - val_loss: 0.6668 - val_acc: 0.5967
# Finished training at 4.891252279281616
#
# PFN AUC: 0.6304288714319047
#
# Model summary:
# Train on 70000 samples, validate on 15000 samples
# Epoch 1/3
# 70000/70000 [==============================] - 2s 26us/step - loss: 0.6767 - acc: 0.5843 - val_loss: 0.6700 - val_acc: 0.5929
# Epoch 2/3
# 70000/70000 [==============================] - 1s 17us/step - loss: 0.6698 - acc: 0.5967 - val_loss: 0.6694 - val_acc: 0.5889
# Epoch 3/3
# 70000/70000 [==============================] - 1s 16us/step - loss: 0.6691 - acc: 0.5966 - val_loss: 0.6687 - val_acc: 0.5929
# Finished training at 4.997878789901733
#
# EFN AUC: 0.6335203210940455

# %%
optimal_roc = roc_curve(Y[:,1],-optimal)
optimal_auc = roc_auc_score(Y[:,1],-optimal)
mult_roc = roc_curve(Y[:,1],mults)
mult_auc = roc_auc_score(Y[:,1],mults)
rocs = [pfn_roc,pfn_z_roc,pfn_noz_roc,efn_roc,optimal_roc,mult_roc]
aucs = [pfn_auc,pfn_z_auc,pfn_noz_auc,efn_auc,optimal_auc,mult_auc]
labels = ["PFN",r"PFN[$z$]",r"PFN[$\eta$,$\phi$]","EFN","Predicted","Multiplicity"]
plotting.plot_many(rocs,aucs,labels)
