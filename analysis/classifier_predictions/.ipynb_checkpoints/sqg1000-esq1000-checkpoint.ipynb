# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append("../utils/")
from train_tools import pre_process, train_qg_pfn
from sklearn.metrics import roc_auc_score, roc_curve

# %%
base_dir = "/home/sambt/pythia83-samples/optimal-classifiers/kernel-1/"
fname_gg = base_dir+'H2gg-CF3.0CA3.0-sqg1000-esq0011/total.root'
fname_qq = base_dir+'H2qq-CF3.0CA3.0-sqg1000-esq0011/total.root'

# %%
#loading in data and labels 
X, Y = pre_process(fname_qq,fname_gg)
# Out:
# Loaded files at 0.5691654682159424
# Read in arrays at 28.876749277114868
# Limited max events at 28.87684726715088
# Cleaned events at 30.564464330673218
# Made quark/gluon input arrays at 95.427072763443
# Finished preprocessing at 232.42473816871643

# %%
#Making the 'optimal classifier' in the case that CF = CA, P_g = 1/z, P_q = (1/z)*exp(z+z^2)
#Optimal classifier should be n^(1) + n^(2)
optimal = np.array([1 + np.sum([p[0]**2 for p in jet]) for jet in X])
optimal_roc = roc_curve(Y[:,1],-optimal)

# %%
pfn_out = train_qg_pfn(fname_qq,fname_gg,n_epoch=3,nev_max=100000)
# Out:
# Loaded files at 0.5683925151824951
# Read in arrays at 28.145315647125244
# Limited max events at 28.145422220230103
# Cleaned events at 28.314255714416504
# qmaxmult = 18, gmaxmult = 17
# Made quark/gluon input arrays at 35.38346743583679
# Finished preprocessing at 49.07153797149658
# Done train/val/test split at 49.109935998916626
# Model summary:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, None, 3)      0
# __________________________________________________________________________________________________
# tdist_0 (TimeDistributed)       (None, None, 100)    400         input[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, 100)    0           tdist_0[0][0]
# __________________________________________________________________________________________________
# tdist_1 (TimeDistributed)       (None, None, 100)    10100       activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, 100)    0           tdist_1[0][0]
# __________________________________________________________________________________________________
# tdist_2 (TimeDistributed)       (None, None, 128)    12928       activation_9[0][0]
# __________________________________________________________________________________________________
# mask (Lambda)                   (None, None)         0           input[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, 128)    0           tdist_2[0][0]
# __________________________________________________________________________________________________
# sum (Dot)                       (None, 128)          0           mask[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# dense_0 (Dense)                 (None, 100)          12900       sum[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 100)          0           dense_0[0][0]
# __________________________________________________________________________________________________
# dense_0_dropout (Dropout)       (None, 100)          0           activation_11[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          10100       dense_0_dropout[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 100)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_1_dropout (Dropout)       (None, 100)          0           activation_12[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          10100       dense_1_dropout[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 100)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_2_dropout (Dropout)       (None, 100)          0           activation_13[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 2)            202         dense_2_dropout[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 2)            0           output[0][0]
# ==================================================================================================
# Total params: 56,730
# Trainable params: 56,730
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 137197 samples, validate on 29399 samples
# Epoch 1/3
# 137197/137197 [==============================] - 3s 19us/step - loss: 0.7224 - acc: 0.5179 - val_loss: 0.6896 - val_acc: 0.5420
# Epoch 2/3
# 137197/137197 [==============================] - 2s 15us/step - loss: 0.6895 - acc: 0.5377 - val_loss: 0.6852 - val_acc: 0.5509
# Epoch 3/3
# 137197/137197 [==============================] - 2s 15us/step - loss: 0.6876 - acc: 0.5460 - val_loss: 0.6850 - val_acc: 0.5525
# Finished training at 56.66482710838318
#
# PFN AUC: 0.5664432135722861

# %%
pfn_roc = pfn_out[1][0]

plt.rcParams['figure.figsize'] = (8,8)
plt.rcParams['font.family'] = 'serif'
plt.rcParams['figure.autolayout'] = True

pfn_fp, pfn_tp, threshs = pfn_roc
opt_fp, opt_tp, opt_thresh = optimal_roc
plt.plot(pfn_tp, 1-pfn_fp, '-', label='PFN ROC')
plt.plot(opt_tp,1-opt_fp,"-",label="Optimal ROC")

# axes labels
plt.xlabel('Quark Jet Efficiency',fontsize=14)
plt.ylabel('Gluon Jet Rejection',fontsize=14)

# axes limits
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# make legend and show plot
plt.legend(loc='lower left', frameon=False,fontsize=14)
plt.text(0.45,0.03,r"$C_F$ = $C_A$ = 3, Kernel Order = $-1$",fontsize=16)
plt.show()
