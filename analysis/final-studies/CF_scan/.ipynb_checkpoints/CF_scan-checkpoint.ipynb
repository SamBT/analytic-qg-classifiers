# %%
from tqdm import tqdm
import sys
import importlib
sys.path.append("/home/sambt/analytic-qg-classifiers/analysis/utils/")
from master import *
prefix = '/home/sambt/pythia83-samples/optimal-classifiers/kernel-1/'
CFs = ["0.0","0.3","0.7","1.0","1.3","1.7","2.0","2.3","2.7","3.0"]
CF_labels = [r'$C_F = {0}/3$'.format(k) if k%3 > 0 else r'$C_F = {0}$'.format(int(k/3)) for k in np.arange(10)]

# %%
rocs_CF = []
aucs_CF = []
dummy_f = lambda x : np.sum(x,axis=1)
for CF in CFs:
    rocs,aucs,labels = analysis.run_pfn('H2qq-CF'+CF+'CA3.0-sqg0100','H2gg-CF3.0CA3.0-sqg0100-r0.4',dummy_f,F_dropouts=0.2)
    rocs_CF.append(rocs[0])
    aucs_CF.append(aucs[0])
# Out:
# Loaded files at 0.08086371421813965
# Read in arrays at 1.6502025127410889
# Cleaned events at 1.7321968078613281
# Made quark/gluon input arrays at 4.265149354934692
# Finished preprocessing at 10.291548728942871
# Training PFN
# PFN AUC: 0.979664962632425
# Loaded files at 0.07459521293640137
# Read in arrays at 1.5882625579833984
# Cleaned events at 1.6685826778411865
# Made quark/gluon input arrays at 4.150810480117798
# Finished preprocessing at 9.983701229095459
# Training PFN
# PFN AUC: 0.895763346510799
# Loaded files at 0.07581377029418945
# Read in arrays at 1.6845378875732422
# Cleaned events at 1.7644093036651611
# Made quark/gluon input arrays at 4.380017042160034
# Finished preprocessing at 10.210572957992554
# Training PFN
# PFN AUC: 0.8131967060164793
# Loaded files at 0.07618188858032227
# Read in arrays at 1.6939892768859863
# Cleaned events at 1.7914800643920898
# Made quark/gluon input arrays at 4.648445129394531
# Finished preprocessing at 10.975577116012573
# Training PFN
# PFN AUC: 0.7422576708000618
# Loaded files at 0.07532072067260742
# Read in arrays at 1.58359956741333
# Cleaned events at 1.664463996887207
# Made quark/gluon input arrays at 4.156422138214111
# Finished preprocessing at 9.98779559135437
# Training PFN
# PFN AUC: 0.683950640965789
# Loaded files at 0.07838726043701172
# Read in arrays at 1.5977351665496826
# Cleaned events at 1.6779675483703613
# Made quark/gluon input arrays at 4.140018463134766
# Finished preprocessing at 10.188289642333984
# Training PFN
# PFN AUC: 0.634561138290891
# Loaded files at 0.07587742805480957
# Read in arrays at 1.6343560218811035
# Cleaned events at 1.7154831886291504
# Made quark/gluon input arrays at 4.59115195274353
# Finished preprocessing at 10.619840383529663
# Training PFN
# PFN AUC: 0.5864320447276439
# Loaded files at 0.07576203346252441
# Read in arrays at 1.582559585571289
# Cleaned events at 1.6623964309692383
# Made quark/gluon input arrays at 4.046660423278809
# Finished preprocessing at 9.903598308563232
# Training PFN
# PFN AUC: 0.5460688566093409
# Loaded files at 0.05365490913391113
# Read in arrays at 1.5809504985809326
# Cleaned events at 1.6614408493041992
# Made quark/gluon input arrays at 4.6613335609436035
# Finished preprocessing at 10.793646574020386
# Training PFN
# PFN AUC: 0.5288756916995485
# Loaded files at 0.07696652412414551
# Read in arrays at 1.614978551864624
# Cleaned events at 1.6939771175384521
# Made quark/gluon input arrays at 4.596067905426025
# Finished preprocessing at 10.981582403182983
# Training PFN
# PFN AUC: 0.5030295498959773

# %%
importlib.reload(plotting)
plt.figure(1,(10,10))
ax = plt.gca()
plotting.plot_many(rocs_CF,aucs_CF,CF_labels,ax,ncol=2,fontsize=20)
plotting.stamp(0.02,0.5,line_3=r'$\sqrt{s} = 250$ GeV',fontsize=24,delta_y=0.045)
plt.savefig("CFscan_PFN.pdf")

# %%
rocs_CF = []
aucs_CF = []
dummy_f = lambda x : np.sum(x,axis=1)
for CF in CFs:
    rocs,aucs,labels = analysis.run_pfn('H2qq-CF'+CF+'CA3.0-sqg0100','H2gg-CF3.0CA3.0-sqg0100-r0.4',dummy_f,F_dropouts=0.25)
    rocs_CF.append(rocs[0])
    aucs_CF.append(aucs[0])
# Out:
# Loaded files at 0.0809478759765625
# Read in arrays at 1.7900948524475098
# Cleaned events at 1.8714959621429443
# Made quark/gluon input arrays at 4.292466402053833
# Finished preprocessing at 10.651301145553589
# Training PFN
# PFN AUC: 0.9812533970174532
# Loaded files at 0.07684135437011719
# Read in arrays at 1.5987544059753418
# Cleaned events at 1.6778147220611572
# Made quark/gluon input arrays at 4.102712631225586
# Finished preprocessing at 10.625472068786621
# Training PFN
# PFN AUC: 0.8877985538101756
# Loaded files at 0.06966042518615723
# Read in arrays at 1.6064224243164062
# Cleaned events at 1.687948226928711
# Made quark/gluon input arrays at 4.4285805225372314
# Finished preprocessing at 11.390579223632812
# Training PFN
# PFN AUC: 0.8084401040599866
# Loaded files at 0.05502009391784668
# Read in arrays at 1.6592495441436768
# Cleaned events at 1.7386085987091064
# Made quark/gluon input arrays at 4.059018611907959
# Finished preprocessing at 10.546104907989502
# Training PFN
# PFN AUC: 0.7325104875835406
# Loaded files at 0.05598711967468262
# Read in arrays at 1.5955336093902588
# Cleaned events at 1.6749634742736816
# Made quark/gluon input arrays at 4.2453086376190186
# Finished preprocessing at 10.714921236038208
# Training PFN
# PFN AUC: 0.6852890044309049
# Loaded files at 0.07679009437561035
# Read in arrays at 1.7945401668548584
# Cleaned events at 1.878943681716919
# Made quark/gluon input arrays at 4.343318700790405
# Finished preprocessing at 10.841404914855957
# Training PFN
# PFN AUC: 0.6231250939223041
# Loaded files at 0.05501389503479004
# Read in arrays at 1.5772602558135986
# Cleaned events at 1.6563539505004883
# Made quark/gluon input arrays at 4.521312713623047
# Finished preprocessing at 11.061625003814697
# Training PFN
# PFN AUC: 0.588574863597917
# Loaded files at 0.0781865119934082
# Read in arrays at 1.7708134651184082
# Cleaned events at 1.8492779731750488
# Made quark/gluon input arrays at 4.339700222015381
# Finished preprocessing at 10.922779083251953
# Training PFN
# PFN AUC: 0.5524745290493487
# Loaded files at 0.05552935600280762
# Read in arrays at 1.650615930557251
# Cleaned events at 1.732208251953125
# Made quark/gluon input arrays at 4.402233839035034
# Finished preprocessing at 11.053654670715332
# Training PFN
# PFN AUC: 0.5277773219743281
# Loaded files at 0.054946184158325195
# Read in arrays at 1.7247514724731445
# Cleaned events at 1.8056766986846924
# Made quark/gluon input arrays at 4.906496286392212
# Finished preprocessing at 11.630697011947632
# Training PFN
# PFN AUC: 0.5043958831786634

# %%
importlib.reload(plotting)
plt.figure(1,(10,10))
ax = plt.gca()
plotting.plot_many(rocs_CF,aucs_CF,CF_labels,ax,ncol=2)
plotting.stamp(0.02,0.5,line_3=r'$\sqrt{s} = 250$ GeV')
plt.savefig("CFscan_PFN_dropouts_0.25.pdf")
