# %%
from tqdm import tqdm
import sys
import importlib
sys.path.append("/home/sambt/analytic-qg-classifiers/analysis/utils/")
from master import *
prefix = '/home/sambt/pythia83-samples/optimal-classifiers/kernel-1/'

# %%
f_opt = lambda x : np.sum(x*np.log(x,where=x>0,out=np.zeros(x.shape)),axis=1)
rocs_r4,aucs_r4,labels_r4 = analysis.run_pipeline('H2qq-CF3.0CA3.0-sqg0100-esq0010-r0.4','H2gg-CF3.0CA3.0-sqg0100-r0.4',f_opt)
rocs_r1,aucs_r1,labels_r1 = analysis.run_pipeline('H2qq-CF3.0CA3.0-sqg0100-esq0010-r1.0','H2gg-CF3.0CA3.0-sqg0100-r1.0',f_opt)
rocs_r15,aucs_r15,labels_r15 = analysis.run_pipeline('H2qq-CF3.0CA3.0-sqg0100-esq0010-r1.5','H2gg-CF3.0CA3.0-sqg0100-r1.5',f_opt)
# Out:
# Loaded files at 0.0659177303314209
# Read in arrays at 1.6528377532958984
# Cleaned events at 1.7349631786346436
# Made quark/gluon input arrays at 4.31032133102417
# Finished preprocessing at 10.606298685073853
# Training PFN
# PFN AUC: 0.6009541185563597
# Training PFN[z]
# PFN[z] AUC: 0.5509024872453334
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.5977288925698852
# Training EFN
# EFN AUC: 0.5995341387844095
# Loaded files at 0.07892751693725586
# Read in arrays at 1.6846179962158203
# Cleaned events at 1.7660884857177734
# Made quark/gluon input arrays at 6.510738134384155
# Finished preprocessing at 13.381797313690186
# Training PFN
# PFN AUC: 0.6215593576595154
# Training PFN[z]
# PFN[z] AUC: 0.6135109873772828
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.6177259832301681
# Training EFN
# EFN AUC: 0.6219132454061687
# Loaded files at 0.0814824104309082
# Read in arrays at 1.968888521194458
# Cleaned events at 2.0515973567962646
# ...

# %%
importlib.reload(plotting)
fig,axes = plt.subplots(2,2,figsize=(20,20))
ax1 = plt.subplot(221)
plotting.plot_many(rocs_r4,aucs_r4,labels_r4,ax1,fontsize=22)
plotting.stamp(0.02,0.6,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z}$',fontsize=24)
ax2 = plt.subplot(222)
plotting.plot_many(rocs_r1,aucs_r1,labels_r1,ax2,fontsize=22)
plotting.stamp(0.02,0.6,radius=1.0,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z}$',fontsize=24)
ax3 = plt.subplot(223)
plotting.plot_many(rocs_r15,aucs_r15,labels_r15,ax3,fontsize=22)
plotting.stamp(0.05,0.6,radius=1.5,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z}$',fontsize=24)
# Out:
# Text(0.02, 0.35, '$P_{q \\to qg} \\propto e^{z}$')

# %%
labels_r4 = [x if "Predicted" not in x else r'$n_S^{(1)}$ ' for x in labels_r4]
labels_r1 = [x if "Predicted" not in x else r'$n_S^{(1)}$ ' for x in labels_r1]
labels_r15 = [x if "Predicted" not in x else r'$n_S^{(1)}$ ' for x in labels_r15]

plt.figure(figsize=(10,10))
plotting.plot_many(rocs_r4,aucs_r4,labels_r4,plt.gca(),fontsize=20)
plotting.stamp(0.02,0.6,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z}$',fontsize=24)
plt.savefig("plots/ROCs_CF3.0CA3.0_shannon_sqg0100-esq0010-r0.4.pdf")

plt.figure(figsize=(10,10))
plotting.plot_many(rocs_r1,aucs_r1,labels_r1,plt.gca(),fontsize=20)
plotting.stamp(0.02,0.6,radius=1.0,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z}$',fontsize=24)
plt.savefig("plots/ROCs_CF3.0CA3.0_shannon_sqg0100-esq0010-r1.0.pdf")

plt.figure(figsize=(10,10))
plotting.plot_many(rocs_r15,aucs_r15,labels_r15,plt.gca(),fontsize=20)
plotting.stamp(0.05,0.6,radius=1.5,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z}$',fontsize=24)
plt.savefig("plots/ROCs_CF3.0CA3.0_shannon_sqg0100-esq0010-r1.5.pdf")
