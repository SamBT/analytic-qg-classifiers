# %%
from tqdm import tqdm
import sys
import importlib
sys.path.append("/home/sambt/analytic-qg-classifiers/analysis/utils/")
from master import *
prefix = '/home/sambt/pythia83-samples/optimal-classifiers/kernel-1/'

# %%
f_opt = lambda x : np.sum(np.power(x,2,where=x>0,out=np.zeros(x.shape)) + x*np.log(x,where=x>0,out=np.zeros(x.shape)),axis=1)
rocs_r4,aucs_r4,labels_r4 = analysis.run_pipeline('H2qq-CF3.0CA3.0-sqg0100-esq0011-r0.4','H2gg-CF3.0CA3.0-sqg0100-r0.4',f_opt)
rocs_r1,aucs_r1,labels_r1 = analysis.run_pipeline('H2qq-CF3.0CA3.0-sqg0100-esq0011-r1.0','H2gg-CF3.0CA3.0-sqg0100-r1.0',f_opt)
rocs_r15,aucs_r15,labels_r15 = analysis.run_pipeline('H2qq-CF3.0CA3.0-sqg0100-esq0011-r1.5','H2gg-CF3.0CA3.0-sqg0100-r1.5',f_opt)
# Out:
# Loaded files at 0.0654611587524414
# Read in arrays at 1.6864206790924072
# Cleaned events at 1.768120527267456
# Made quark/gluon input arrays at 4.369206428527832
# Finished preprocessing at 11.22095274925232
# Training PFN
# PFN AUC: 0.6434728429212792
# Training PFN[z]
# PFN[z] AUC: 0.5722974767596282
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.6308530846316704
# Training EFN
# EFN AUC: 0.6368218899407525
# Loaded files at 0.07839035987854004
# Read in arrays at 1.74068284034729
# Cleaned events at 1.8205790519714355
# Made quark/gluon input arrays at 6.7387847900390625
# Finished preprocessing at 13.570004940032959
# Training PFN
# PFN AUC: 0.6747945893324007
# Training PFN[z]
# PFN[z] AUC: 0.6692163344112458
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.6878679848865742
# Training EFN
# EFN AUC: 0.6885788245901141
# Loaded files at 0.07961416244506836
# Read in arrays at 1.784538984298706
# Cleaned events at 1.8622338771820068
# ...

# %%
importlib.reload(plotting)
fig,axes = plt.subplots(2,2,figsize=(20,20))
ax1 = plt.subplot(221)
plotting.plot_many(rocs_r4,aucs_r4,labels_r4,ax1,fontsize=22)
plotting.stamp(0.02,0.6,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z+z^2}$',fontsize=24)
ax2 = plt.subplot(222)
plotting.plot_many(rocs_r1,aucs_r1,labels_r1,ax2,fontsize=22)
plotting.stamp(0.02,0.6,radius=1.0,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z+z^2}$',fontsize=24)
ax3 = plt.subplot(223)
plotting.plot_many(rocs_r15,aucs_r15,labels_r15,ax3,fontsize=22)
plotting.stamp(0.05,0.6,radius=1.5,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z+z^2}$',fontsize=24)
# Out:
# Text(0.02, 0.35, '$P_{q \\to qg} \\propto e^{z+z^2}$')

# %%
labels_r4 = [x if "n^{(1)}" not in x else r'$n_S^{(1)}+n^{(2)}$ ' for x in labels_r4]
labels_r1 = [x if "n^{(1)}" not in x else r'$n_S^{(1)}+n^{(2)}$ ' for x in labels_r1]
labels_r15 = [x if "n^{(1)}" not in x else r'$n_S^{(1)}+n^{(2)}$ ' for x in labels_r15]

plt.figure(figsize=(10,10))
plotting.plot_many(rocs_r4,aucs_r4,labels_r4,plt.gca(),fontsize=20)
plotting.stamp(0.02,0.6,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z+z^2}$',fontsize=24)
plt.savefig("plots/ROCs_CF3.0CA3.0_shannon_sqg0100-esq0011-r0.4.pdf")

plt.figure(figsize=(10,10))
plotting.plot_many(rocs_r1,aucs_r1,labels_r1,plt.gca(),fontsize=20)
plotting.stamp(0.02,0.6,radius=1.0,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z+z^2}$',fontsize=24)
plt.savefig("plots/ROCs_CF3.0CA3.0_shannon_sqg0100-esq0011-r1.0.pdf")

plt.figure(figsize=(10,10))
plotting.plot_many(rocs_r15,aucs_r15,labels_r15,plt.gca(),fontsize=20)
plotting.stamp(0.05,0.6,radius=1.5,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z+z^2}$',fontsize=24)
plt.savefig("plots/ROCs_CF3.0CA3.0_shannon_sqg0100-esq0011-r1.5.pdf")
