# %%
from tqdm import tqdm
import sys
import importlib
sys.path.append("/home/sambt/analytic-qg-classifiers/analysis/utils/")
from master import *
prefix = '/home/sambt/pythia83-samples/optimal-classifiers/kernel-1/'

# %%
f_opt = lambda x : np.count_nonzero(x,axis=1) + np.sum(np.power(x,2,where=x>0,out=np.zeros(x.shape)),axis=1)
#f_opt = lambda x : np.count_nonzero(x,axis=1) + np.sum(np.power(x,2,where=x>0,out=np.zeros(x.shape)),axis=1)
rocs_r4,aucs_r4,labels_r4 = analysis.run_pipeline('H2qq-CF3.0CA3.0-sqg0100-esq0001-r0.4','H2gg-CF3.0CA3.0-sqg0100-r0.4',f_opt)
rocs_r1,aucs_r1,labels_r1 = analysis.run_pipeline('H2qq-CF3.0CA3.0-sqg0100-esq0001-r1.0','H2gg-CF3.0CA3.0-sqg0100-r1.0',f_opt)
rocs_r15,aucs_r15,labels_r15 = analysis.run_pipeline('H2qq-CF3.0CA3.0-sqg0100-esq0001-r1.5','H2gg-CF3.0CA3.0-sqg0100-r1.5',f_opt)
# Out:
# Loaded files at 0.08253908157348633
# Read in arrays at 1.6928181648254395
# Cleaned events at 1.7762677669525146
# Made quark/gluon input arrays at 4.4230756759643555
# Finished preprocessing at 10.623006343841553
# Training PFN
# PFN AUC: 0.5680095853070425
# Training PFN[z]
# PFN[z] AUC: 0.5323498312605921
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.561206600114274
# Training EFN
# EFN AUC: 0.5740559712466602
# Loaded files at 0.07938790321350098
# Read in arrays at 1.7276606559753418
# Cleaned events at 1.8085851669311523
# Made quark/gluon input arrays at 6.71345067024231
# Finished preprocessing at 13.240049839019775
# Training PFN
# PFN AUC: 0.5877979940088097
# Training PFN[z]
# PFN[z] AUC: 0.5846650078535314
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.5726233387539834
# Training EFN
# EFN AUC: 0.5916268863429481
# Loaded files at 0.07928824424743652
# Read in arrays at 1.785677433013916
# Cleaned events at 1.8890924453735352
# ...

# %%
importlib.reload(plotting)
fig,axes = plt.subplots(2,2,figsize=(20,20))
split = r'$P_{q \to qg} \propto e^{z^2}$'
ax1 = plt.subplot(221)
plotting.plot_many(rocs_r4,aucs_r4,labels_r4,ax1,fontsize=20)
plotting.stamp(0.02,0.6,fontsize=22,delta_y=0.04)
plt.text(0.02,0.35,split,fontsize=24)
ax2 = plt.subplot(222)
plotting.plot_many(rocs_r1,aucs_r1,labels_r1,ax2,fontsize=20)
plotting.stamp(0.02,0.6,radius=1.0,fontsize=22,delta_y=0.04)
plt.text(0.02,0.35,split,fontsize=24)
ax3 = plt.subplot(223)
plotting.plot_many(rocs_r15,aucs_r15,labels_r15,ax3,fontsize=20)
plotting.stamp(0.05,0.6,radius=1.5,fontsize=22,delta_y=0.04)
plt.text(0.02,0.35,split,fontsize=24)
# Out:
# Text(0.02, 0.35, '$P_{q \\to qg} \\propto e^{z^2}$')

# %%
labels_r4 = [x if "Predicted" not in x else r'$n^{(2)}$ ' for x in labels_r4]
labels_r1 = [x if "Predicted" not in x else r'$n^{(2)}$ ' for x in labels_r1]
labels_r15 = [x if "Predicted" not in x else r'$n^{(2)}$ ' for x in labels_r15]

plt.figure(figsize=(10,10))
plotting.plot_many(rocs_r4,aucs_r4,labels_r4,plt.gca(),fontsize=20)
plotting.stamp(0.02,0.6,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z^2}$',fontsize=24)
plt.savefig("plots/ROCs_CF3.0CA3.0_sqg0100-esq0001-r0.4.pdf")

plt.figure(figsize=(10,10))
plotting.plot_many(rocs_r1,aucs_r1,labels_r1,plt.gca(),fontsize=20)
plotting.stamp(0.02,0.6,radius=1.0,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z^2}$',fontsize=24)
plt.savefig("plots/ROCs_CF3.0CA3.0_sqg0100-esq0001-r1.0.pdf")

plt.figure(figsize=(10,10))
plotting.plot_many(rocs_r15,aucs_r15,labels_r15,plt.gca(),fontsize=20)
plotting.stamp(0.05,0.6,radius=1.5,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z^2}$',fontsize=24)
plt.savefig("plots/ROCs_CF3.0CA3.0_sqg0100-esq0001-r1.5.pdf")
