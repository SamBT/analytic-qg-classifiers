# %%
from tqdm import tqdm
import sys
import importlib
sys.path.append("/home/sambt/analytic-qg-classifiers/analysis/utils/")
from master import *
prefix = '/home/sambt/pythia83-samples/optimal-classifiers/kernel-1/'
modpath = '/home/sambt/analytic-qg-classifiers/analysis/final-studies/saved_models/'

# %%
f_opt = lambda x : np.sum(np.power(x,2,where=x>0,out=np.zeros(x.shape)) + x,axis=1)
rocs_r4,aucs_r4,labels_r4 = analysis.run_pipeline('H2qq-CF3.0CA3.0-sqg0100-esq0011-r0.4','H2gg-CF3.0CA3.0-sqg0100-r0.4',f_opt)
rocs_r1,aucs_r1,labels_r1 = analysis.run_pipeline('H2qq-CF3.0CA3.0-sqg0100-esq0011-r1.0','H2gg-CF3.0CA3.0-sqg0100-r1.0',f_opt)
rocs_r15,aucs_r15,labels_r15 = analysis.run_pipeline('H2qq-CF3.0CA3.0-sqg0100-esq0011-r1.5','H2gg-CF3.0CA3.0-sqg0100-r1.5',f_opt)
# Out:
# Loaded files at 0.0807955265045166
# Read in arrays at 1.7151658535003662
# Cleaned events at 1.7968297004699707
# Made quark/gluon input arrays at 4.373737573623657
# Finished preprocessing at 10.236343145370483
# Training PFN
# PFN AUC: 0.636743834622824
# Training PFN[z]
# PFN[z] AUC: 0.5737773814800469
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.6236204689902649
# Training EFN
# EFN AUC: 0.6204653957212592
# Loaded files at 0.08093595504760742
# Read in arrays at 1.8825113773345947
# Cleaned events at 1.9621732234954834
# Made quark/gluon input arrays at 6.674536228179932
# Finished preprocessing at 12.755379438400269
# Training PFN
# PFN AUC: 0.686815516469704
# Training PFN[z]
# PFN[z] AUC: 0.6648434168646307
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.6764323696318473
# Training EFN
# EFN AUC: 0.6807540131183963
# Loaded files at 0.07548880577087402
# Read in arrays at 1.8869168758392334
# Cleaned events at 1.9623737335205078
# Made quark/gluon input arrays at 7.3326921463012695
# Finished preprocessing at 13.664467573165894
# Training PFN
# PFN AUC: 0.7113713471473407
# Training PFN[z]
# PFN[z] AUC: 0.7045328372345854
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.7096304886870388
# Training EFN
# EFN AUC: 0.7005418214504249

# %%
importlib.reload(plotting)
fig,axes = plt.subplots(2,2,figsize=(20,20))
ax1 = plt.subplot(221)
plotting.plot_many(rocs_r4,aucs_r4,labels_r4,ax1,fontsize=22)
plotting.stamp(0.02,0.6,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z+z^2}$',fontsize=24)
ax2 = plt.subplot(222)
plotting.plot_many(rocs_r1,aucs_r1,labels_r1,ax2,fontsize=22)
plotting.stamp(0.02,0.6,radius=1.0,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z+z^2}$',fontsize=24)
ax3 = plt.subplot(223)
plotting.plot_many(rocs_r15,aucs_r15,labels_r15,ax3,fontsize=22)
plotting.stamp(0.05,0.6,radius=1.5,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z+z^2}$',fontsize=24)
# Out:
# Text(0.02, 0.35, '$P_{q \\to qg} \\propto e^{z+z^2}$')

# %%
labels_r4 = [x if "Predicted" not in x else r'$n^{(1)}+n^{(2)}$ ' for x in labels_r4]
labels_r1 = [x if "Predicted" not in x else r'$n^{(1)}+n^{(2)}$ ' for x in labels_r1]
labels_r15 = [x if "Predicted" not in x else r'$n^{(1)}+n^{(2)}$ ' for x in labels_r15]

plt.figure(figsize=(10,10))
plotting.plot_many(rocs_r4,aucs_r4,labels_r4,plt.gca(),fontsize=20)
plotting.stamp(0.02,0.6,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z+z^2}$',fontsize=24)
plt.savefig("plots/ROCs_CF3.0CA3.0_sqg0100-esq0011-r0.4.pdf")

plt.figure(figsize=(10,10))
plotting.plot_many(rocs_r1,aucs_r1,labels_r1,plt.gca(),fontsize=20)
plotting.stamp(0.02,0.6,radius=1.0,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z+z^2}$',fontsize=24)
plt.savefig("plots/ROCs_CF3.0CA3.0_sqg0100-esq0011-r1.0.pdf")

plt.figure(figsize=(10,10))
plotting.plot_many(rocs_r15,aucs_r15,labels_r15,plt.gca(),fontsize=20)
plotting.stamp(0.05,0.6,radius=1.5,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z+z^2}$',fontsize=24)
plt.savefig("plots/ROCs_CF3.0CA3.0_sqg0100-esq0011-r1.5.pdf")
