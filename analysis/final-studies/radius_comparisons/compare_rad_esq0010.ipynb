# %%
from tqdm import tqdm
import sys
import importlib
sys.path.append("/home/sambt/analytic-qg-classifiers/analysis/utils/")
from master import *
prefix = '/home/sambt/pythia83-samples/optimal-classifiers/kernel-1/'

# %%
f_opt = lambda x : np.sum(x,axis=1)
rocs_r4,aucs_r4,labels_r4 = analysis.run_pipeline('H2qq-CF3.0CA3.0-sqg0100-esq0010-r0.4','H2gg-CF3.0CA3.0-sqg0100-r0.4',f_opt)
rocs_r1,aucs_r1,labels_r1 = analysis.run_pipeline('H2qq-CF3.0CA3.0-sqg0100-esq0010-r1.0','H2gg-CF3.0CA3.0-sqg0100-r1.0',f_opt)
rocs_r15,aucs_r15,labels_r15 = analysis.run_pipeline('H2qq-CF3.0CA3.0-sqg0100-esq0010-r1.5','H2gg-CF3.0CA3.0-sqg0100-r1.5',f_opt)
# Out:
# Loaded files at 0.08191061019897461
# Read in arrays at 1.752997636795044
# Cleaned events at 1.8430898189544678
# Made quark/gluon input arrays at 4.580301523208618
# Finished preprocessing at 11.03508472442627
# Training PFN
# PFN AUC: 0.6053857055507998
# Training PFN[z]
# PFN[z] AUC: 0.5555072098215366
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.5876186871870709
# Training EFN
# EFN AUC: 0.5979932724560703
# Loaded files at 0.07725191116333008
# Read in arrays at 1.8975718021392822
# Cleaned events at 1.9820165634155273
# Made quark/gluon input arrays at 7.154918193817139
# Finished preprocessing at 14.44818925857544
# Training PFN
# PFN AUC: 0.6165803561550625
# Training PFN[z]
# PFN[z] AUC: 0.6152005194664909
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.6068957059922019
# Training EFN
# EFN AUC: 0.6151191887074934
# Loaded files at 0.07711291313171387
# Read in arrays at 1.7695555686950684
# Cleaned events at 1.8465766906738281
# Made quark/gluon input arrays at 7.105277061462402
# Finished preprocessing at 14.633577585220337
# Training PFN
# PFN AUC: 0.6526199441413285
# Training PFN[z]
# PFN[z] AUC: 0.6387106697138728
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.6347828818553103
# Training EFN
# EFN AUC: 0.6297826619214126

# %%
importlib.reload(plotting)
fig,axes = plt.subplots(2,2,figsize=(20,20))
ax1 = plt.subplot(221)
plotting.plot_many(rocs_r4,aucs_r4,labels_r4,ax1,fontsize=22)
plotting.stamp(0.02,0.6,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z}$',fontsize=24)
ax2 = plt.subplot(222)
plotting.plot_many(rocs_r1,aucs_r1,labels_r1,ax2,fontsize=22)
plotting.stamp(0.02,0.6,radius=1.0,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z}$',fontsize=24)
ax3 = plt.subplot(223)
plotting.plot_many(rocs_r15,aucs_r15,labels_r15,ax3,fontsize=22)
plotting.stamp(0.05,0.6,radius=1.5,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z}$',fontsize=24)
# Out:
# Text(0.02, 0.35, '$P_{q \\to qg} \\propto e^{z}$')

# %%
labels_r4 = [x if "Predicted" not in x else r'$n^{(1)}$ ' for x in labels_r4]
labels_r1 = [x if "Predicted" not in x else r'$n^{(1)}$ ' for x in labels_r1]
labels_r15 = [x if "Predicted" not in x else r'$n^{(1)}$ ' for x in labels_r15]

plt.figure(figsize=(10,10))
plotting.plot_many(rocs_r4,aucs_r4,labels_r4,plt.gca(),fontsize=20)
plotting.stamp(0.02,0.6,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z}$',fontsize=24)
plt.savefig("plots/ROCs_CF3.0CA3.0_sqg0100-esq0010-r0.4.pdf")

plt.figure(figsize=(10,10))
plotting.plot_many(rocs_r1,aucs_r1,labels_r1,plt.gca(),fontsize=20)
plotting.stamp(0.02,0.6,radius=1.0,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z}$',fontsize=24)
plt.savefig("plots/ROCs_CF3.0CA3.0_sqg0100-esq0010-r1.0.pdf")

plt.figure(figsize=(10,10))
plotting.plot_many(rocs_r15,aucs_r15,labels_r15,plt.gca(),fontsize=20)
plotting.stamp(0.05,0.6,radius=1.5,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,r'$P_{q \to qg} \propto e^{z}$',fontsize=24)
plt.savefig("plots/ROCs_CF3.0CA3.0_sqg0100-esq0010-r1.5.pdf")
