# %%
from tqdm import tqdm
import sys
sys.path.append("/home/sambt/analytic-qg-classifiers/analysis/utils/")
from master import *
prefix = '/home/sambt/pythia83-samples/optimal-classifiers/kernel-1/'

# %%
f_opt = lambda x : np.sum(np.power(x,2,where=x>0,out=np.zeros(x.shape)) + x*np.log(x,where=x>0,out=np.zeros(x.shape)),axis=1)
pred = r'$n_S^{(0)} + n^{(2)}$'
rocs_r4,aucs_r4,labels_r4 = analysis.run_pipeline('H2qq-CF3.0CA3.0-sqg0100-esq0011-r0.4','H2gg-CF3.0CA3.0-sqg0100-r0.4',f_opt,predicted=pred)
# Out:
# Loaded files at 0.08212447166442871
# Read in arrays at 1.6635735034942627
# Cleaned events at 1.7455413341522217
# Made quark/gluon input arrays at 4.328600168228149
# Finished preprocessing at 10.840291976928711
# Training PFN
# PFN AUC: 0.6445430904787832
# Training PFN[z]
# PFN[z] AUC: 0.5608770180673885
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.6298038490616018
# Training EFN
# EFN AUC: 0.6300845137969084

# %%
plt.figure(figsize=(10,10))
ax = plt.gca()
split = r'$P_{q \to qg} \propto e^{z+z^2}$'
plotting.plot_many(rocs_r4,aucs_r4,labels_r4,ax,fontsize=20)
plotting.stamp(0.02,0.6,fontsize=22,delta_y=0.045)
plt.text(0.02,0.35,split,fontsize=24)
#plt.savefig('plots/ROCs_shannon_CF3.0CA3.0_sqg0100-esq0011-r0.4.pdf')
# Out:
# Text(0.02, 0.35, '$P_{q \\to qg} \\propto e^{z+z^2}$')
