# %%
from tqdm import tqdm
import importlib
import sys
sys.path.append("/home/sambt/analytic-qg-classifiers/analysis/utils/")
from master import *
prefix = '/home/sambt/pythia83-samples/optimal-classifiers/kernel-1/'

# %%
#Scan with R = 0.4
ez2s = [1,5,10,100]
roc_ez2s = {}
auc_ez2s = {}
lab_ez2s = {}
for ez2 in ez2s:
    f_opt = lambda x : np.sum(ez2*np.power(x,2,where=x>0,out=np.zeros(x.shape)) + x,axis=1)
    rocs,aucs,labels = analysis.run_pipeline('H2qq-CF3.0CA3.0-sqg0100-esq001{0}-r0.4'.format(ez2),'H2gg-CF3.0CA3.0-sqg0100-r0.4',f_opt)
    roc_ez2s[ez2] = rocs
    auc_ez2s[ez2] = aucs
    lab_ez2s[ez2] = labels
# Out:
# Loaded files at 0.08271050453186035
# Read in arrays at 1.738070011138916
# Cleaned events at 1.821948766708374
# Made quark/gluon input arrays at 4.41259503364563
# Finished preprocessing at 10.641388893127441
# Training PFN
# PFN AUC: 0.631493224455254
# Training PFN[z]
# PFN[z] AUC: 0.5723137794618499
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.629697203654921
# Training EFN
# EFN AUC: 0.6304113984904572
# Loaded files at 0.07902097702026367
# Read in arrays at 1.7417542934417725
# Cleaned events at 1.8221874237060547
# Made quark/gluon input arrays at 4.69075870513916
# Finished preprocessing at 10.835370779037476
# Training PFN
# PFN AUC: 0.6860517779938707
# Training PFN[z]
# PFN[z] AUC: 0.576651872061788
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.6749824493734113
# Training EFN
# EFN AUC: 0.6788638411904161
# Loaded files at 0.07885026931762695
# Read in arrays at 1.7665400505065918
# Cleaned events at 1.8458566665649414
# Made quark/gluon input arrays at 4.429187059402466
# Finished preprocessing at 10.773589134216309
# Training PFN
# PFN AUC: 0.6902177916922164
# Training PFN[z]
# PFN[z] AUC: 0.5718469844267822
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.6851672783153899
# Training EFN
# EFN AUC: 0.6751178267916118
# Loaded files at 0.05669522285461426
# Read in arrays at 1.670492172241211
# Cleaned events at 1.747542381286621
# Made quark/gluon input arrays at 4.611539125442505
# Finished preprocessing at 10.772106885910034
# Training PFN
# PFN AUC: 0.6936555040522558
# Training PFN[z]
# PFN[z] AUC: 0.5787946806094791
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.6832037832174084
# Training EFN
# EFN AUC: 0.6753168512198029

# %%
importlib.reload(plotting)
fig, axes = plt.subplots(2,2,figsize=(20,20))
for i,ez2 in enumerate(ez2s):
    ax = plt.subplot(220+i+1)
    rocs,aucs,labels = roc_ez2s[ez2],auc_ez2s[ez2],lab_ez2s[ez2]
    plotting.plot_many(rocs,aucs,labels,ax)
    plotting.stamp(0.02,0.6)
    split = r'$P_{q \to qg} \propto e^{z+'+str(ez2)+'z^2}$' if ez2 > 1 else r'$P_{q \to qg} \propto e^{z+z^2}$'
    plt.text(0.02,0.35,split,fontsize=24)
plt.savefig("plots/cz2_scan_esq001n_r0p4.pdf")

# %%
#Scan with R = 1.0
ez2s = [1,5,10,100]
roc_ez2s_r1 = {}
auc_ez2s_r1 = {}
lab_ez2s_r1 = {}
for ez2 in ez2s:
    f_opt = lambda x : np.sum(ez2*np.power(x,2,where=x>0,out=np.zeros(x.shape)) + x,axis=1)
    rocs,aucs,labels = analysis.run_pipeline('H2qq-CF3.0CA3.0-sqg0100-esq001{0}-r1.0'.format(ez2),'H2gg-CF3.0CA3.0-sqg0100-r1.0',f_opt)
    roc_ez2s_r1[ez2] = rocs
    auc_ez2s_r1[ez2] = aucs
    lab_ez2s_r1[ez2] = labels
# Out:
# Loaded files at 0.08019089698791504
# Read in arrays at 1.6611721515655518
# Cleaned events at 1.741877555847168
# Made quark/gluon input arrays at 6.443636894226074
# Finished preprocessing at 12.777782678604126
# Training PFN
# PFN AUC: 0.6735114043534209
# Training PFN[z]
# PFN[z] AUC: 0.6630465754609193
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.6844258499079534
# Training EFN
# EFN AUC: 0.6883859237270773
# Loaded files at 0.07184052467346191
# Read in arrays at 1.8239519596099854
# Cleaned events at 1.9008336067199707
# Made quark/gluon input arrays at 6.7064714431762695
# Finished preprocessing at 12.980084419250488
# Training PFN
# PFN AUC: 0.7723374126232265
# Training PFN[z]
# PFN[z] AUC: 0.7503284065899138
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.76573819766854
# Training EFN
# EFN AUC: 0.7793468320171852
# Loaded files at 0.07727503776550293
# Read in arrays at 1.7963523864746094
# Cleaned events at 1.873079538345337
# Made quark/gluon input arrays at 6.585319995880127
# Finished preprocessing at 12.826627969741821
# Training PFN
# PFN AUC: 0.7927049655427463
# Training PFN[z]
# PFN[z] AUC: 0.7579795455951138
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.7865366015619362
# Training EFN
# EFN AUC: 0.7947787587740598
# Loaded files at 0.06209707260131836
# Read in arrays at 1.7851037979125977
# Cleaned events at 1.8614709377288818
# Made quark/gluon input arrays at 6.368501901626587
# Finished preprocessing at 12.708055019378662
# Training PFN
# PFN AUC: 0.7937099304692412
# Training PFN[z]
# PFN[z] AUC: 0.7596719542433725
# Training PFN[eta,phi]
# PFN[eta,phi] AUC: 0.7885359040979615
# Training EFN
# EFN AUC: 0.789134762141332

# %%
fig, axes = plt.subplots(2,2,figsize=(20,20))
for i,ez2 in enumerate(ez2s):
    ax = plt.subplot(220+i+1)
    rocs,aucs,labels = roc_ez2s_r1[ez2],auc_ez2s_r1[ez2],lab_ez2s_r1[ez2]
    plotting.plot_many(rocs,aucs,labels,ax)
    plotting.stamp(0.02,0.6,radius=1.0)
    split = r'$P_{q \to qg} \propto e^{z+'+str(ez2)+'z^2}$' if ez2 > 1 else r'$P_{q \to qg} \propto e^{z+z^2}$'
    plt.text(0.02,0.35,split,fontsize=24)
plt.savefig("plots/cz2_scan_esq001n_r1p0.pdf")
