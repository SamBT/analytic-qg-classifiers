# %%
import sys
from tqdm import tqdm
sys.path.append("/home/sambt/analytic-qg-classifiers/analysis/utils/")
from master import *
prefix = '/home/sambt/pythia83-samples/optimal-classifiers/kernel-1/'

# %%
h2qq_samples = {"qgsame":prefix+'H2qq-CF3.0CA3.0-sqg0100-esq0000-r1.0/total.root', 
                "esq0001":prefix+'H2qq-CF3.0CA3.0-sqg0100-esq0001-r1.0/total.root', 
                "esq0011":prefix+'H2qq-CF3.0CA3.0-sqg0100-esq0011-r1.0/total.root'}
fg = prefix+'H2gg-CF3.0CA3.0-sqg0100-r1.0/total.root'
samples = list(h2qq_samples.keys())

# %%
z_collection = {}
eta_collection = {}
phi_collection = {}
dR_collection = {}
label_collection = {}
for samp, fq in h2qq_samples.items():
    X,Y = tools.pre_process(fq,fg,nev_max=50000)
    z = X[:,:,0].copy()
    dEta = X[:,:,1].copy()
    dPhi = X[:,:,2].copy()
    dR = np.sqrt(dEta**2 + dPhi**2)
    
    z_collection[samp] = z.copy()
    eta_collection[samp] = dEta.copy()
    phi_collection[samp] = dPhi.copy()
    dR_collection[samp] = dR.copy()
    label_collection[samp] = Y[:,1].copy()
    
    del X, Y, z, dEta, dPhi, dR
# Out:
# Loaded files at 0.07093262672424316
# Read in arrays at 1.8559329509735107
# Cleaned events at 1.9380784034729004
# Made quark/gluon input arrays at 6.689598798751831
# Finished preprocessing at 13.20425033569336
# Loaded files at 0.054022789001464844
# Read in arrays at 1.614997386932373
# Cleaned events at 1.6934068202972412
# Made quark/gluon input arrays at 6.395574331283569
# Finished preprocessing at 12.825334310531616
# Loaded files at 0.053205013275146484
# Read in arrays at 1.7301554679870605
# Cleaned events at 1.809027910232544
# Made quark/gluon input arrays at 6.709950923919678
# Finished preprocessing at 13.184803247451782

# %%
exp_z = np.linspace(-3,3,num=31)
exp_theta = np.linspace(-3,3,num=31)

aucs_2d_collection = {}
for samp in samples:
    z = z_collection[samp]
    dR = dR_collection[samp]
    labs = label_collection[samp]
    aucs_2d = np.zeros((exp_z.size,exp_theta.size))
    for i, ez in enumerate(tqdm(exp_z)):
        for j, et in enumerate(exp_theta):
            zpow = np.power(z,ez,where=z>0.0,out=np.zeros(z.shape))
            rpow = np.power(dR,et,where=dR>0.0,out=np.zeros(dR.shape))
            opt = np.sum(zpow*rpow,axis=1)
            auc = roc_auc_score(labs,opt)
            if auc < 0.5:
                auc = 1-auc
            aucs_2d[i,j] = auc
    
    aucs_2d_collection[samp] = aucs_2d
# Out:
# 100%|██████████| 31/31 [01:55<00:00,  3.72s/it]
# 100%|██████████| 31/31 [01:59<00:00,  3.85s/it]
# 100%|██████████| 31/31 [02:02<00:00,  3.96s/it]

# %%
aucs_2d_collection = {}
for samp in samples:
    aucs_2d_collection[samp] = np.load('angularity_scan_auc2d_grid_'+samp+'.npy')

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['figure.autolayout'] = True
plt.rcParams['text.usetex'] = True

titles = {"qgsame":r'$P_{q\to qg}\propto 1$, $R = 1.0$, $C_F = C_A = 3$',"esq0001":r'$P_{q\to qg} \propto e^{z^2}$, $R = 1.0$, $C_F = C_A = 3$',"esq0011":r'$P_{q\to qg} \propto e^{z+z^2}$, $R = 1.0$, $C_F = C_A = 3$'}
plt.figure(1,(20,20))
for i, samp in enumerate(samples):
    plt.subplot(2,2,i+1)
    aucs_2d = aucs_2d_collection[samp]
    print(aucs_2d.max(),aucs_2d.min())
    auc_grid = plt.imshow(aucs_2d.transpose(),origin='lower',extent=(-3.1,3.1,-3.1,3.1),vmin=0.50,vmax=aucs_2d.max())
    plt.title(titles[samp],fontsize=28)
    #plt.colorbar(auc_grid)
    bar = plt.colorbar(auc_grid,fraction=0.045)
    bar.ax.tick_params(labelsize=16)
    bar.set_label("AUC",fontsize=20)
    plt.xlabel(r"$z_i$ exponent ($\kappa$)",fontsize=24)
    plt.ylabel(r"$\theta_i$ exponent ($\beta$)",fontsize=24)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
#plt.tight_layout()
plt.savefig("plots/angularity_scans_r1.0.pdf")
# Out:
# 0.5058314023999999 0.5000515104
# 0.5853641954000001 0.5001559786
# 0.6751411794000001 0.5002041201999999

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['figure.autolayout'] = True
plt.rcParams['text.usetex'] = True

for i, samp in enumerate(samples):
    plt.figure(figsize=(10,10))
    aucs_2d = aucs_2d_collection[samp]
    print(aucs_2d.max(),aucs_2d.min())
    auc_grid = plt.imshow(aucs_2d.transpose(),origin='lower',extent=(-3.1,3.1,-3.1,3.1),vmin=0.50,vmax=aucs_2d.max())
    plt.title(titles[samp],fontsize=28)
    #plt.colorbar(auc_grid)
    bar = plt.colorbar(auc_grid,fraction=0.045)
    bar.ax.tick_params(labelsize=16)
    bar.set_label("AUC",fontsize=20)
    plt.xlabel(r"$z_i$ exponent ($\kappa$)",fontsize=24)
    plt.ylabel(r"$\theta_i$ exponent ($\beta$)",fontsize=24)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.savefig("plots/angularity_scan_"+samp+"_r1.0.pdf")
# Out:
# 0.5058314023999999 0.5000515104
# 0.5853641954000001 0.5001559786
# 0.6751411794000001 0.5002041201999999

# %%
np.save("saved_numpy_data/angularity_scan_exp_z_r1.0",exp_z)
np.save("saved_numpy_data/angularity_scan_exp_theta_r1.0",exp_theta)
for i, samp in enumerate(samples):
    aucs_2d = aucs_2d_collection[samp]
    np.save("saved_numpy_data/angularity_scan_auc_grid_"+samp+"_r1.0",aucs_2d)

# %%
import matplotlib.patches as patches
for i, samp in enumerate(samples):
    print("Analyzing sample "+samp)
    aucs_2d = aucs_2d_collection[samp]
    n = 20
    worst = np.argsort(aucs_2d,axis=None)
    worst_kappas = []
    best_kappas = []
    worst_betas = []
    best_betas = []
    best_aucs = []
    worst_aucs = []
    for k in range(n):
        ix_bad, iy_bad = np.unravel_index(worst[k],aucs_2d.shape)
        k_bad = exp_z[ix_bad]
        b_bad = exp_theta[iy_bad]
        auc_bad = aucs_2d[ix_bad,iy_bad]
        worst_kappas.append(k_bad)
        worst_betas.append(b_bad)
        worst_aucs.append(auc_bad)
        print("{0}th worst AUC is {1:.6f} at kappa = {2:.2f}, beta = {3:.2f}".format(k,aucs_2d[ix_bad,iy_bad],exp_z[ix_bad],exp_theta[iy_bad]))

        ix_good, iy_good = np.unravel_index(worst[-1-k],aucs_2d.shape)
        k_good = exp_z[ix_good]
        b_good = exp_theta[iy_good]
        auc_good = aucs_2d[ix_good,iy_good]
        best_kappas.append(k_good)
        best_betas.append(b_good)
        best_aucs.append(auc_good)
        print("{0}th best AUC is {1:.6f} at kappa = {2:.2f}, beta = {3:.2f}".format(k,aucs_2d[ix_good,iy_good],exp_z[ix_good],exp_theta[iy_good]))
    plt.figure(figsize=(10,10))
    ax = plt.gca()
    best_aucs = np.array(best_aucs)
    worst_aucs = np.array(worst_aucs)
    alpha_good = tools.mapto(best_aucs,0.25,1)
    alpha_bad = tools.mapto(-worst_aucs,0.25,1)
    alpha_good = np.clip(alpha_good,0.25,1)
    alpha_bad = np.clip(alpha_bad,0.25,1)
    plt.xlim([-3,3])
    plt.ylim([-3,3])
    plt.gca().set_xticks(np.linspace(-3,3,num=13))
    plt.gca().set_yticks(np.linspace(-3,3,num=13))
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.grid(zorder=1)
    for i in range(n):
        #plt.scatter(best_kappas[i],best_betas[i],s=144,color="green",alpha=alpha_good[i])
        #plt.scatter(worst_kappas[i],worst_betas[i],s=144,color="red",alpha=alpha_bad[i])
        r1 = patches.Rectangle((best_kappas[i]-0.1,best_betas[i]-0.1),0.2,0.2,color="green",alpha=alpha_good[i],zorder=2)
        r2 = patches.Rectangle((worst_kappas[i]-0.1,worst_betas[i]-0.1),0.2,0.2,color="red",alpha=alpha_bad[i],zorder=2)
        ax.add_patch(r1)
        ax.add_patch(r2)
    plt.xlabel(r"$z_i$ exponent ($\kappa$)",fontsize=24)
    plt.ylabel(r"$\theta_i$ exponent ($\beta$)",fontsize=24)
    plt.title(titles[samp],fontsize=24)
    plt.savefig("plots/best{0}_angularities_".format(n)+samp+"_r1.0.pdf")
    print("----------------")
# Out:
# Analyzing sample qgsame
# 0th worst AUC is 0.500052 at kappa = -3.00, beta = -0.60
# 0th best AUC is 0.505831 at kappa = 1.40, beta = 3.00
# 1th worst AUC is 0.500058 at kappa = 0.40, beta = -0.20
# 1th best AUC is 0.505825 at kappa = 1.60, beta = 3.00
# 2th worst AUC is 0.500067 at kappa = -2.80, beta = -0.60
# 2th best AUC is 0.505820 at kappa = 1.40, beta = 2.80
# 3th worst AUC is 0.500073 at kappa = -0.60, beta = -0.40
# 3th best AUC is 0.505811 at kappa = 1.80, beta = 3.00
# 4th worst AUC is 0.500081 at kappa = -2.60, beta = -0.60
# 4th best AUC is 0.505807 at kappa = 1.60, beta = 2.80
# 5th worst AUC is 0.500104 at kappa = -2.40, beta = -0.60
# 5th best AUC is 0.505804 at kappa = 1.20, beta = 2.80
# 6th worst AUC is 0.500120 at kappa = -0.40, beta = -0.40
# 6th best AUC is 0.505804 at kappa = 1.20, beta = 2.60
# 7th worst AUC is 0.500132 at kappa = -2.20, beta = -0.60
# 7th best AUC is 0.505798 at kappa = 1.40, beta = 2.60
# 8th worst AUC is 0.500168 at kappa = -2.00, beta = -0.60
# 8th best AUC is 0.505795 at kappa = 1.20, beta = 3.00
# 9th worst AUC is 0.500190 at kappa = -2.60, beta = -0.40
# 9th best AUC is 0.505789 at kappa = 1.20, beta = 2.40
# 10th worst AUC is 0.500193 at kappa = -2.40, beta = -0.40
# 10th best AUC is 0.505785 at kappa = 2.00, beta = 3.00
# 11th worst AUC is 0.500195 at kappa = -2.80, beta = -0.40
# 11th best AUC is 0.505782 at kappa = 1.80, beta = 2.80
# 12th worst AUC is 0.500197 at kappa = -2.20, beta = -0.40
# 12th best AUC is 0.505779 at kappa = 1.60, beta = 2.60
# 13th worst AUC is 0.500203 at kappa = -2.00, beta = -0.40
# 13th best AUC is 0.505773 at kappa = 1.00, beta = 2.40
# 14th worst AUC is 0.500206 at kappa = -3.00, beta = -0.40
# 14th best AUC is 0.505772 at kappa = 1.40, beta = 2.40
# 15th worst AUC is 0.500210 at kappa = -1.80, beta = -0.40
# 15th best AUC is 0.505772 at kappa = 1.00, beta = 2.20
# 16th worst AUC is 0.500215 at kappa = -0.80, beta = -0.40
# 16th best AUC is 0.505764 at kappa = 1.00, beta = 2.60
# 17th worst AUC is 0.500215 at kappa = 2.60, beta = 0.40
# 17th best AUC is 0.505762 at kappa = 1.20, beta = 2.20
# 18th worst AUC is 0.500216 at kappa = -1.80, beta = -0.60
# 18th best AUC is 0.505756 at kappa = 2.20, beta = 3.00
# 19th worst AUC is 0.500217 at kappa = -1.60, beta = -0.40
# 19th best AUC is 0.505755 at kappa = 2.00, beta = 2.80
# ----------------
# Analyzing sample esq0001
# 0th worst AUC is 0.500156 at kappa = 1.80, beta = 0.40
# 0th best AUC is 0.585364 at kappa = 0.20, beta = 0.20
# 1th worst AUC is 0.501163 at kappa = -1.40, beta = -1.80
# 1th best AUC is 0.585228 at kappa = 0.40, beta = 0.20
# 2th worst AUC is 0.501183 at kappa = -1.20, beta = -1.60
# 2th best AUC is 0.584166 at kappa = 0.00, beta = 0.20
# 3th worst AUC is 0.501387 at kappa = -1.60, beta = -2.00
# 3th best AUC is 0.583850 at kappa = 0.60, beta = 0.20
# 4th worst AUC is 0.501625 at kappa = -2.40, beta = -3.00
# 4th best AUC is 0.583565 at kappa = 0.20, beta = 0.40
# 5th worst AUC is 0.501669 at kappa = -1.00, beta = -1.40
# 5th best AUC is 0.583332 at kappa = 0.40, beta = 0.40
# 6th worst AUC is 0.501739 at kappa = -1.80, beta = -2.20
# 6th best AUC is 0.582392 at kappa = 0.00, beta = 0.40
# 7th worst AUC is 0.501745 at kappa = 0.00, beta = -0.60
# 7th best AUC is 0.582254 at kappa = 0.20, beta = 0.00
# 8th worst AUC is 0.502146 at kappa = -2.00, beta = -2.40
# 8th best AUC is 0.582227 at kappa = 0.40, beta = 0.00
# 9th worst AUC is 0.502266 at kappa = 2.20, beta = 0.60
# 9th best AUC is 0.581793 at kappa = 0.60, beta = 0.40
# 10th worst AUC is 0.502309 at kappa = 1.40, beta = 0.20
# 10th best AUC is 0.581643 at kappa = 0.60, beta = 0.00
# 11th worst AUC is 0.502430 at kappa = -2.20, beta = -2.80
# 11th best AUC is 0.581436 at kappa = 0.40, beta = 0.60
# 12th worst AUC is 0.502565 at kappa = -2.20, beta = -2.60
# 12th best AUC is 0.581250 at kappa = -0.20, beta = 0.20
# 13th worst AUC is 0.502981 at kappa = -0.80, beta = -1.20
# 13th best AUC is 0.581155 at kappa = 0.20, beta = 0.60
# 14th worst AUC is 0.502982 at kappa = -2.40, beta = -2.80
# 14th best AUC is 0.580967 at kappa = 0.00, beta = 0.00
# 15th worst AUC is 0.503304 at kappa = -2.00, beta = -2.60
# 15th best AUC is 0.580795 at kappa = 0.80, beta = 0.00
# 16th worst AUC is 0.503378 at kappa = -2.60, beta = -3.00
# 16th best AUC is 0.580676 at kappa = 0.80, beta = 0.20
# 17th worst AUC is 0.504016 at kappa = 1.00, beta = 0.00
# 17th best AUC is 0.580280 at kappa = 0.60, beta = 0.60
# 18th worst AUC is 0.504063 at kappa = 2.60, beta = 0.80
# 18th best AUC is 0.579466 at kappa = 0.00, beta = 0.60
# 19th worst AUC is 0.504257 at kappa = -1.80, beta = -2.40
# 19th best AUC is 0.579464 at kappa = -0.20, beta = 0.40
# ----------------
# Analyzing sample esq0011
# 0th worst AUC is 0.500204 at kappa = -0.20, beta = -0.80
# 0th best AUC is 0.675141 at kappa = 0.40, beta = 0.20
# 1th worst AUC is 0.500505 at kappa = -2.00, beta = -2.60
# 1th best AUC is 0.675004 at kappa = 0.20, beta = 0.20
# 2th worst AUC is 0.500531 at kappa = 2.60, beta = 0.80
# 2th best AUC is 0.672808 at kappa = 0.60, beta = 0.20
# 3th worst AUC is 0.501215 at kappa = -1.80, beta = -2.40
# 3th best AUC is 0.672298 at kappa = 0.20, beta = 0.40
# 4th worst AUC is 0.502082 at kappa = -2.20, beta = -2.80
# 4th best AUC is 0.672228 at kappa = 0.00, beta = 0.20
# 5th worst AUC is 0.503043 at kappa = -1.60, beta = -2.20
# 5th best AUC is 0.672010 at kappa = 0.40, beta = 0.40
# 6th worst AUC is 0.503506 at kappa = 2.20, beta = 0.60
# 6th best AUC is 0.669791 at kappa = 0.00, beta = 0.40
# 7th worst AUC is 0.503515 at kappa = -2.40, beta = -3.00
# 7th best AUC is 0.669209 at kappa = 0.60, beta = 0.40
# 8th worst AUC is 0.503949 at kappa = 3.00, beta = 1.00
# 8th best AUC is 0.668651 at kappa = 0.40, beta = 0.60
# 9th worst AUC is 0.504931 at kappa = -1.40, beta = -2.00
# 9th best AUC is 0.668075 at kappa = 0.20, beta = 0.60
# 10th worst AUC is 0.505254 at kappa = 1.00, beta = 0.00
# 10th best AUC is 0.667812 at kappa = 0.40, beta = 0.00
# 11th worst AUC is 0.506429 at kappa = -0.40, beta = -1.00
# 11th best AUC is 0.667672 at kappa = 0.20, beta = 0.00
# 12th worst AUC is 0.506761 at kappa = -2.20, beta = -3.00
# 12th best AUC is 0.666951 at kappa = 0.80, beta = 0.20
# 13th worst AUC is 0.506772 at kappa = -1.20, beta = -1.80
# 13th best AUC is 0.666751 at kappa = 0.60, beta = 0.00
# 14th worst AUC is 0.508284 at kappa = 1.80, beta = 0.40
# 14th best AUC is 0.666401 at kappa = 0.60, beta = 0.60
# 15th worst AUC is 0.508328 at kappa = -1.00, beta = -1.60
# 15th best AUC is 0.666104 at kappa = -0.20, beta = 0.20
# 16th worst AUC is 0.508927 at kappa = -0.60, beta = -1.20
# 16th best AUC is 0.665002 at kappa = 0.80, beta = 0.00
# 17th worst AUC is 0.509096 at kappa = -2.00, beta = -2.80
# 17th best AUC is 0.664933 at kappa = 0.00, beta = 0.00
# 18th worst AUC is 0.509240 at kappa = -0.80, beta = -1.40
# 18th best AUC is 0.664866 at kappa = 0.40, beta = 0.80
# 19th worst AUC is 0.509639 at kappa = -1.40, beta = -1.80
# 19th best AUC is 0.664698 at kappa = 0.00, beta = 0.60
# ----------------

# %%
def mapto(arr,xmin,xmax):
    r = xmax - xmin
    d = arr.max() - arr.min()
    out = r*arr/d
    out = out - out.min() + xmin
    return out

plt.figure(2,(10,10))
for i, samp in enumerate(samples):
    plt.subplot(2,2,i+1)
    aucs_2d = aucs_2d_collection[samp]
    aucs_2d = mapto(aucs_2d,0,1)
    auc_grid = plt.imshow(aucs_2d.transpose(),origin='lower',extent=(-4.1,10.1,-4.1,10.1),vmin=0,vmax=1)
    plt.title(samp)
    plt.colorbar(auc_grid)
    plt.xlabel(r"$z_i$ exponent ($\kappa$)",fontsize=18)
    plt.ylabel(r"$\theta_i$ exponent ($\beta$)",fontsize=18)
plt.tight_layout()
plt.savefig("angularity_scan_all_normalized.pdf")

# %%
plt.figure(3,(25,25))
samples_reduced = ["esq0001","esq0011","esq1000"]
for i, samp1 in enumerate(samples_reduced):
    ref_auc2d = aucs_2d_collection[samp1]
    ref_auc2d = tools.mapto(ref_auc2d,0,1)
    plt.subplot(3,3,3*i+i+1)
    img = plt.imshow(ref_auc2d.transpose(),origin='lower',vmin=0,vmax=1,extent=(-4.1,10.1,-4.1,10.1))
    plt.title(samp1)
    plt.colorbar(img)
    for j in range(i+1,len(samples_reduced)):
        samp2 = samples_reduced[j]
        plt.subplot(3,3,3*i+j+1)
        diff_auc2d = aucs_2d_collection[samp2]
        diff_auc2d = tools.mapto(diff_auc2d,0,1)
        delta = ref_auc2d - diff_auc2d
        auc_grid = plt.imshow(delta.transpose(),origin='lower',extent=(-4.1,10.1,-4.1,10.1),vmin=-0.2,vmax=0.2,cmap='seismic')
        plt.title(samp1+" - "+samp2)
        plt.colorbar(auc_grid)
        plt.xlabel(r"$z_i$ exponent ($\kappa$)",fontsize=12)
        plt.ylabel(r"$\theta_i$ exponent ($\beta$)",fontsize=12)
plt.tight_layout()
plt.savefig("angularity_scan_difference_grid.pdf")

# %%
np.save("angularity_scan_z_exponents",exp_z)
np.save("angularity_scan_theta_exponents",exp_theta)
for samp in samples:
    np.save("angularity_scan_auc2d_grid_"+samp,aucs_2d_collection[samp])
