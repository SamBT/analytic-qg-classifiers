# %%
import ROOT
import numpy as np
# Out:
# Welcome to JupyROOT 6.18/00

# %%
f1 = ROOT.TFile("test_initAfterSettings.root")
f2 = ROOT.TFile("test_ReReadNoReInit.root")
f3 = ROOT.TFile("test_ReReadReInit.root")
f4 = ROOT.TFile("/global/project/projectdirs/atlas/sambt/pythia83-output/optimal-classifiers/kernel-1/H2qq-CF3.0CA3.0-sqg0100-esq0011-r0.4/total.root")
f5 = ROOT.TFile("/global/project/projectdirs/atlas/sambt/pythia83-output/optimal-classifiers/kernel-1/H2gg-CF3.0CA3.0-sqg0100-r0.4/total.root")
f6 = ROOT.TFile("/global/project/projectdirs/atlas/sambt/pythia83-output/optimal-classifiers/kernel-1/H2qq-CF3.0CA3.0-sqg0100-esq0000-r0.4/total.root")
f7 = ROOT.TFile("test_cmdlineargs_sqg0011.root")

# %%
t1 = f1.Get("EventTree")
n1 = t1.GetEntries()
t1.SetLineColor(1)
t2 = f2.Get("EventTree")
n2 = t2.GetEntries()
t2.SetLineColor(2)
t3 = f3.Get("EventTree")
n3 = t3.GetEntries()
t3.SetLineColor(3)
t4 = f4.Get("EventTree")
n4 = t4.GetEntries()
t4.SetLineColor(4)
t5 = f5.Get("EventTree")
n5 = t5.GetEntries()
t5.SetLineColor(6)
t6 = f6.Get("EventTree")
n6 = t6.GetEntries()
t6.SetLineColor(7)
t7 = f7.Get("EventTree")
n7 = t7.GetEntries()
t7.SetLineColor(8)

# %%
var = "jet_mult[0]"
c = ROOT.TCanvas("c","c")
t1.Draw("jet_mult[0]","({0:.8f})*(1)".format(1.0/n1),"hist")
#t2.Draw(var,"({0:.8f})*(1)".format(1.0/n2),"histsame")
#t3.Draw(var,"({0:.8f})*(1)".format(1.0/n3),"histsame")
t4.Draw(var,"({0:.8f})*(1)".format(1.0/n4),"histsame")
#t5.Draw(var,"({0:.8f})*(1)".format(1.0/n5),"histsame")
t6.Draw(var,"({0:.8f})*(1)".format(1.0/n6),"histsame")
#t7.Draw(var,"({0:.8f})*(1)".format(1.0/n7),"histsame")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
